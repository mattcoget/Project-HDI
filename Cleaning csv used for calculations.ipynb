# %%
import pandas as pd
import os

# %%
os.chdir('C:\\Users\\mcoge\\Project-HDI\\data\\Calcultations')

# %%
os.listdir()
# Out:
# ['Education Index.csv',
#  'Expected years of schooling (years).csv',
#  'Life expectancy at birth.csv',
#  'Life expectancy index',
#  'Life expectancy Index.csv',
#  'life_expectancy_cleaned.csv',
#  'Mean years of schooling (years).csv',
#  'Population, total (millions).csv',
#  'population_cleaned.csv',
#  'Total population (millions).csv']

# %% [markdown]
# # Clean population csv

# %%
file='Total population (millions).csv'

# %%
population=pd.read_csv(file)

# %%
population.head()
# Out:
#                                             HDI Rank       Country  1990  \
# 0  Total population (millions)\nnull\nDimension: ...           NaN   NaN
# 1                                                169   Afghanistan  12.4
# 2                                                 69       Albania   3.3
# 3                                                 91       Algeria  25.8
# 4                                                 36       Andorra   0.1
#
#   Unnamed: 3  1995 Unnamed: 5  2000 Unnamed: 7  2005 Unnamed: 9  ...  2016  \
# 0        NaN   NaN        NaN   NaN        NaN   NaN        NaN  ...   NaN
# 1        NaN  18.1        NaN  20.8        NaN  25.7        NaN  ...  35.4
# 2        NaN   3.1        NaN   3.1        NaN   3.1        NaN  ...   2.9
# 3        NaN  28.8        NaN  31.0        NaN  33.1        NaN  ...  40.6
# 4        NaN   0.1        NaN   0.1        NaN   0.1        NaN  ...   0.1
#
# ...

# %%
population.drop(['HDI Rank', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13',
                 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23', 'Unnamed: 25',
                 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31'], axis=1, inplace=True)

# %%
population.tail(30)
# Out:
#                                                Country    1990    1995  \
# 190                                             Zambia     8.0     9.1
# 191                                           Zimbabwe    10.4    11.4
# 192                                  Human Development              ..
# 193                        Very high human development  1309.5  1352.3
# 194                             High human development  2216.0  2371.3
# 195                           Medium human development  1339.3  1489.7
# 196                              Low human development   407.3   472.5
# 197                               Developing Countries  4186.6  4573.5
# 198                                            Regions              ..
# 199                                        Arab States   220.3   250.5
# 200                          East Asia and the Pacific  1650.1  1757.8
# 201                            Europe and Central Asia   206.1   212.4
# ...

# %%
population=population[1:192]

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 1 to 191
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  191 non-null    object
#  1   1990     191 non-null    float32
#  2   1995     191 non-null    float32
#  3   2000     191 non-null    float32
#  4   2005     191 non-null    float32
#  5   2010     191 non-null    float32
#  6   2011     191 non-null    float32
#  7   2012     191 non-null    float32
#  8   2013     191 non-null    float32
#  9   2014     191 non-null    float32
#  10  2015     191 non-null    float32
#  11  2016     191 non-null    float32
#  12  2017     191 non-null    float32
#  13  2018     191 non-null    float32
#  14  2019     191 non-null    float32
#  15  2030     191 non-null    float32
# dtypes: float32(15), object(1)
# memory usage: 12.8+ KB

# %%
population=population.replace('..', '').replace(' ', '')

# %%
# Select the columns to transform it into float excluding the Country column
cols = population.columns[population.dtypes.eq('object')]
cols=cols.drop('Country')
population[cols]=population[cols].apply(pd.to_numeric, downcast='float')
population.head()
# Out:
#         Country       1990       1995       2000       2005       2010  \
# 1   Afghanistan  12.400000  18.100000  20.799999  25.700001  29.200001
# 2       Albania   3.300000   3.100000   3.100000   3.100000   2.900000
# 3       Algeria  25.799999  28.799999  31.000000  33.099998  36.000000
# 4       Andorra   0.100000   0.100000   0.100000   0.100000   0.100000
# 5        Angola  11.800000  13.900000  16.400000  19.400000  23.400000
#
#         2011       2012       2013       2014       2015       2016  \
# 1  30.100000  31.200001  32.299999  33.400002  34.400002  35.400002
# 2   2.900000   2.900000   2.900000   2.900000   2.900000   2.900000
# 3  36.700001  37.400002  38.099998  38.900002  39.700001  40.599998
# 4   0.100000   0.100000   0.100000   0.100000   0.100000   0.100000
# 5  24.200001  25.100000  26.000000  26.900000  27.900000  28.799999
#
#         2017       2018       2019       2030
# 1  36.299999  37.200001  38.000000  48.099998
# ...

# %%
population.isna().sum()
# Out:
# Country    0
# 1990       0
# 1995       0
# 2000       0
# 2005       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# 2030       0
# dtype: int64

# %%
population.to_csv("population_cleaned.csv", index=False)

# %% [markdown]
# # Clean Education Index

# %%
os.listdir()
# Out:
# ['Education index.csv',
#  'Expected years of schooling (years).csv',
#  'Life expectancy at birth.csv',
#  'Life expectancy index',
#  'Life expectancy Index.csv',
#  'life_expectancy_cleaned.csv',
#  'Mean years of schooling (years).csv',
#  'Population, total (millions).csv',
#  'population_cleaned.csv',
#  'Total population (millions).csv']

# %%
file='Education Index.csv'

# %%
educ=pd.read_csv(file)

# %%
educ.head()
# Out:
#                                             HDI Rank       Country   1990  \
# 0  Education index\nnull\nDimension: Education\nD...           NaN    NaN
# 1                                                169   Afghanistan  0.122
# 2                                                 69       Albania  0.583
# 3                                                 91       Algeria  0.385
# 4                                                 36       Andorra     ..
#
#    Unnamed: 3   1991  Unnamed: 5   1992  Unnamed: 7   1993  Unnamed: 9  ...  \
# 0         NaN    NaN         NaN    NaN         NaN    NaN         NaN  ...
# 1         NaN  0.133         NaN  0.145         NaN  0.156         NaN  ...
# 2         NaN  0.588         NaN  0.557         NaN  0.542         NaN  ...
# 3         NaN  0.395         NaN  0.405         NaN  0.414         NaN  ...
# 4         NaN     ..         NaN     ..         NaN     ..         NaN  ...
#
# ...

# %%
educ.columns
# Out:
# Index(['HDI Rank', 'Country', '1990', 'Unnamed: 3', '1991', 'Unnamed: 5',
#        '1992', 'Unnamed: 7', '1993', 'Unnamed: 9', '1994', 'Unnamed: 11',
#        '1995', 'Unnamed: 13', '1996', 'Unnamed: 15', '1997', 'Unnamed: 17',
#        '1998', 'Unnamed: 19', '1999', 'Unnamed: 21', '2000', 'Unnamed: 23',
#        '2001', 'Unnamed: 25', '2002', 'Unnamed: 27', '2003', 'Unnamed: 29',
#        '2004', 'Unnamed: 31', '2005', 'Unnamed: 33', '2006', 'Unnamed: 35',
#        '2007', 'Unnamed: 37', '2008', 'Unnamed: 39', '2009', 'Unnamed: 41',
#        '2010', 'Unnamed: 43', '2011', 'Unnamed: 45', '2012', 'Unnamed: 47',
#        '2013', 'Unnamed: 49', '2014', 'Unnamed: 51', '2015', 'Unnamed: 53',
#        '2016', 'Unnamed: 55', '2017', 'Unnamed: 57', '2018', 'Unnamed: 59',
#        '2019', 'Unnamed: 61'],
#       dtype='object')

# %%
educ.drop(['HDI Rank', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13',
           'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23', 'Unnamed: 25',
           'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 37', 
           'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 45', 'Unnamed: 47', 'Unnamed: 49',
           'Unnamed: 51', 'Unnamed: 53', 'Unnamed: 55', 'Unnamed: 57', 'Unnamed: 59', 'Unnamed: 61'],
          axis=1, inplace=True)

# %%
educ.tail(20)
# Out:
#                                                Country   1990   1991   1992  \
# 188                                             Zambia  0.365  0.380  0.396
# 189                                           Zimbabwe  0.423  0.441  0.437
# 190                                  Human Development            ..     ..
# 191                        Very high human development  0.679  0.687  0.680
# 192                             High human development  0.434  0.441  0.449
# 193                           Medium human development  0.302  0.309  0.316
# 194                              Low human development  0.219  0.223  0.226
# 195                               Developing Countries  0.375  0.381  0.388
# 196                                            Regions            ..     ..
# 197                                        Arab States  0.358  0.363  0.370
# 198                          East Asia and the Pacific  0.401  0.408  0.416
# ...

# %%
educ=educ[1:190]

# %%
educ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 1 to 189
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  189 non-null    object
#  1   1990     189 non-null    object
#  2   1991     189 non-null    object
#  3   1992     189 non-null    object
#  4   1993     189 non-null    object
#  5   1994     189 non-null    object
#  6   1995     189 non-null    object
#  7   1996     189 non-null    object
#  8   1997     189 non-null    object
#  9   1998     189 non-null    object
#  10  1999     189 non-null    object
#  11  2000     189 non-null    object
#  12  2001     189 non-null    object
#  13  2002     189 non-null    object
#  14  2003     189 non-null    object
#  15  2004     189 non-null    object
#  16  2005     189 non-null    object
#  17  2006     189 non-null    object
#  18  2007     189 non-null    object
#  19  2008     189 non-null    object
# ...

# %%
educ=educ.replace('..', '').replace(' ', '')

# %%
# Select the columns to transform it into float excluding the Country column
cols = educ.columns[educ.dtypes.eq('object')]
cols=cols.drop('Country')
educ[cols]=educ[cols].apply(pd.to_numeric, downcast='float')
educ.head()
# Out:
#         Country   1990   1991   1992   1993   1994   1995   1996   1997  \
# 1   Afghanistan  0.122  0.133  0.145  0.156  0.168  0.179  0.190  0.202
# 2       Albania  0.583  0.588  0.557  0.542  0.541  0.550  0.557  0.569
# 3       Algeria  0.385  0.395  0.405  0.414  0.424  0.431  0.443  0.458
# 4       Andorra    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5        Angola    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1998  ...   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 1  0.213  ...  0.372  0.374  0.390  0.398  0.403  0.405  0.406  0.408  0.413
# 2  0.579  ...  0.671  0.714  0.739  0.749  0.758  0.753  0.745  0.747  0.743
# 3  0.473  ...  0.626  0.644  0.639  0.639  0.652  0.659  0.660  0.665  0.668
# 4    NaN  ...  0.670  0.671  0.724  0.714  0.725  0.718  0.722  0.713  0.720
# 5    NaN  ...  0.398  0.423  0.435  0.447  0.460  0.472  0.487  0.498  0.500
#
#     2019
# 1  0.414
# 2  0.746
# 3  0.672
# 4  0.720
# 5  0.500
#
# ...

# %%
educ.isna().sum()
# Out:
# Country     0
# 1990       45
# 1991       45
# 1992       46
# 1993       45
# 1994       45
# 1995       41
# 1996       41
# 1997       42
# 1998       41
# 1999       38
# 2000       15
# 2001       15
# 2002       14
# 2003       12
# 2004       10
# 2005        3
# 2006        3
# 2007        3
# 2008        3
# 2009        3
# 2010        1
# 2011        1
# 2012        1
# 2013        1
# 2014        1
# 2015        1
# 2016        1
# 2017        0
# 2018        0
# 2019        0
# dtype: int64

# %%
nas={i:educ.iloc[i].isna().sum() for i in range(len(educ.index)) 
     if educ.iloc[i].isna().sum()/educ.shape[1]>0}

# %%
sorted_na = sorted(nas.items(), key=lambda kv: kv[1])

# %%
sorted_na
# Out:
# [(180, 2),
#  (10, 5),
#  (15, 5),
#  (47, 5),
#  (105, 5),
#  (4, 9),
#  (97, 9),
#  (156, 9),
#  (3, 10),
#  (11, 10),
#  (21, 10),
#  (26, 10),
#  (28, 10),
#  (33, 10),
#  (37, 10),
#  (48, 10),
#  (53, 10),
#  (57, 10),
#  (63, 10),
#  (89, 10),
#  (99, 10),
#  (102, 10),
#  (112, 10),
#  (126, 10),
#  (128, 10),
#  (130, 10),
#  (144, 10),
#  (145, 10),
#  (151, 10),
#  (169, 10),
#  (182, 10),
#  (67, 12),
#  (115, 13),
#  (125, 13),
#  (131, 14),
#  (162, 14),
#  (5, 15),
#  (19, 15),
#  (54, 15),
#  (70, 15),
#  (95, 15),
#  (143, 15),
#  (183, 15),
#  (158, 20),
#  (175, 20),
#  (108, 27)]

# %%
educ.iloc[143]
# Out:
# Country     Saint Kitts and Nevis
# 1990                          NaN
# 1991                          NaN
# 1992                          NaN
# 1993                          NaN
# 1994                          NaN
# 1995                          NaN
# 1996                          NaN
# 1997                          NaN
# 1998                          NaN
# 1999                          NaN
# 2000                          NaN
# 2001                          NaN
# 2002                          NaN
# 2003                          NaN
# 2004                          NaN
# 2005                        0.553
# 2006                        0.564
# 2007                        0.575
# 2008                        0.603
# 2009                        0.609
# 2010                        0.622
# 2011                        0.627
# 2012                        0.616
# 2013                        0.657
# 2014                        0.658
# 2015                        0.654
# ...

# %%
#interpolation works only with numeric columns. So, select numeric columns first
data_numeric=educ._get_numeric_data().copy()

#select numeric columns with missing data
cols_interp=data_numeric.columns[data_numeric.isnull().sum()>0]
cols_interp

#interpolate them
data_numeric[cols_interp]=data_numeric[cols_interp].interpolate(method='linear')

# %%
data_numeric.isna().sum().sum()
# Out:
# 0

# %%
educ[cols_interp]=data_numeric[cols_interp].interpolate(method='linear')

# %%
educ.columns[educ.isna().sum()>0]
# Out:
# Index([], dtype='object')

# %%
educ.iloc[108]
# Out:
# Country     Marshall Islands
# 1990                  0.3915
# 1991                   0.397
# 1992                  0.4045
# 1993                   0.415
# 1994                   0.427
# 1995                   0.431
# 1996                   0.437
# 1997                   0.442
# 1998                   0.456
# 1999                  0.4605
# 2000                  0.4635
# 2001                  0.4695
# 2002                   0.474
# 2003                  0.4845
# 2004                  0.5035
# 2005                   0.524
# 2006                   0.524
# 2007                   0.526
# 2008                   0.525
# 2009                  0.5385
# 2010                  0.5535
# 2011                  0.5535
# 2012                   0.568
# 2013                    0.58
# 2014                  0.5895
# 2015                  0.5935
# 2016                   0.605
# 2017                   0.707
# 2018                   0.707
# 2019                   0.707
# Name: 109, dtype: object

# %%
educ.to_csv('education_index_cleaned.csv', index=False)

# %% [markdown]
# # Clean Expected years of schooling

# %%
os.listdir()
# Out:
# ['Education index.csv',
#  'education_index_cleaned.csv',
#  'Expected years of schooling (years).csv',
#  'Life expectancy at birth (years).csv',
#  'Life expectancy at birth.csv',
#  'Life expectancy index.csv',
#  'life_expectancy_cleaned.csv',
#  'life_expectancy_index_cleaned.csv',
#  'Mean years of schooling (years).csv',
#  'Population, total (millions).csv',
#  'population_cleaned.csv',
#  'Total population (millions).csv']

# %%
file='Expected years of schooling (years).csv'

# %%
schooling=pd.read_csv(file)

# %%
schooling.head()
# Out:
#                                             HDI Rank       Country  1990  \
# 0  Expected years of schooling (years)\nSDG 4.3 B...           NaN   NaN
# 1                                                169   Afghanistan   2.6
# 2                                                 69       Albania  11.6
# 3                                                 91       Algeria   9.6
# 4                                                 36       Andorra  10.8
#
#    Unnamed: 3  1991  Unnamed: 5  1992  Unnamed: 7  1993  Unnamed: 9  ...  \
# 0         NaN   NaN         NaN   NaN         NaN   NaN         NaN  ...
# 1         NaN   2.9         NaN   3.2         NaN   3.6         NaN  ...
# 2         NaN  11.8         NaN  10.7         NaN  10.1         NaN  ...
# 3         NaN   9.7         NaN   9.8         NaN   9.8         NaN  ...
# 4         NaN  10.8         NaN  10.8         NaN  10.8         NaN  ...
#
#    2015  Unnamed: 53  2016  Unnamed: 55  2017  Unnamed: 57  2018  Unnamed: 59  \
# ...

# %%
schooling.drop(['HDI Rank', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 
           'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23',
           'Unnamed: 25', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31', 'Unnamed: 33', 'Unnamed: 35',
           'Unnamed: 37', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 45', 'Unnamed: 47',
           'Unnamed: 49', 'Unnamed: 51', 'Unnamed: 53', 'Unnamed: 55', 'Unnamed: 57', 'Unnamed: 59','Unnamed: 61'],
          axis=1, inplace=True)

# %%
schooling.head()
# Out:
#         Country  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 0           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   Afghanistan   2.6   2.9   3.2   3.6   3.9   4.2   4.6   4.9   5.2  ...
# 2       Albania  11.6  11.8  10.7  10.1  10.1  10.2  10.2  10.5  10.7  ...
# 3       Algeria   9.6   9.7   9.8   9.8   9.9   9.8  10.0  10.3  10.5  ...
# 4       Andorra  10.8  10.8  10.8  10.8  10.8  10.8  10.8  10.8  10.8  ...
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   9.5   9.5  10.0  10.2  10.3  10.2  10.3  10.1  10.1  10.2
# 2  13.0  13.7  14.6  14.9  15.3  15.1  14.8  14.8  14.7  14.7
# 3  14.0  14.3  13.9  13.6  14.0  14.2  14.2  14.4  14.5  14.6
# 4  11.7  11.7  13.5  13.1  13.5  13.1  13.3  13.0  13.3  13.3
#
# [5 rows x 31 columns]

# %%
schooling.tail(30)
# Out:
#                                                Country  1990  1991  1992  \
# 191                                              Yemen   7.5   7.5   7.6
# 192                                             Zambia   7.5   7.7   8.0
# 193                                           Zimbabwe   9.8  10.2   9.8
# 194                                  Human Development          ..    ..
# 195                        Very high human development  13.3  13.4  13.0
# 196                             High human development   9.7   9.7   9.8
# 197                           Medium human development   7.3   7.4   7.5
# 198                              Low human development   5.4   5.4   5.4
# 199                               Developing Countries   8.4   8.5   8.5
# 200                                            Regions          ..    ..
# 201                                        Arab States   8.9   8.9   9.0
# 202                          East Asia and the Pacific   8.9   8.9   9.0
# ...

# %%
schooling=schooling[1:194]

# %%
schooling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 1 to 193
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  193 non-null    object
#  1   1990     193 non-null    object
#  2   1991     193 non-null    object
#  3   1992     193 non-null    object
#  4   1993     193 non-null    object
#  5   1994     193 non-null    object
#  6   1995     193 non-null    object
#  7   1996     193 non-null    object
#  8   1997     193 non-null    object
#  9   1998     193 non-null    object
#  10  1999     193 non-null    object
#  11  2000     193 non-null    object
#  12  2001     193 non-null    object
#  13  2002     193 non-null    object
#  14  2003     193 non-null    object
#  15  2004     193 non-null    object
#  16  2005     193 non-null    object
#  17  2006     193 non-null    object
#  18  2007     193 non-null    object
#  19  2008     193 non-null    object
# ...

# %%
schooling=schooling.replace('..', '').replace(' ', '')

# %%
# Select the columns to transform it into float excluding the Country column
cols = schooling.columns[schooling.dtypes.eq('object')]
cols=cols.drop('Country')
schooling[cols]=schooling[cols].apply(pd.to_numeric, downcast='float')
schooling.head()
# Out:
#         Country  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 1   Afghanistan   2.6   2.9   3.2   3.6   3.9   4.2   4.6   4.9   5.2  ...
# 2       Albania  11.6  11.8  10.7  10.1  10.1  10.2  10.2  10.5  10.7  ...
# 3       Algeria   9.6   9.7   9.8   9.8   9.9   9.8  10.0  10.3  10.5  ...
# 4       Andorra  10.8  10.8  10.8  10.8  10.8  10.8  10.8  10.8  10.8  ...
# 5        Angola   3.4   3.3   3.2   3.7   3.8   3.9   4.0   4.1   4.2  ...
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 1   9.5   9.5  10.0  10.2  10.3  10.2  10.3  10.1  10.1  10.2
# 2  13.0  13.7  14.6  14.9  15.3  15.1  14.8  14.8  14.7  14.7
# 3  14.0  14.3  13.9  13.6  14.0  14.2  14.2  14.4  14.5  14.6
# 4  11.7  11.7  13.5  13.1  13.5  13.1  13.3  13.0  13.3  13.3
# 5   8.6   9.5   9.9  10.3  10.7  11.0  11.4  11.8  11.8  11.8
#
# [5 rows x 31 columns]

# %%
schooling.isna().sum()
# Out:
# Country     0
# 1990       21
# 1991       21
# 1992       22
# 1993       21
# 1994       21
# 1995       18
# 1996       18
# 1997       19
# 1998       18
# 1999       15
# 2000        7
# 2001        6
# 2002        6
# 2003        6
# 2004        6
# 2005        5
# 2006        5
# 2007        5
# 2008        5
# 2009        5
# 2010        3
# 2011        3
# 2012        3
# 2013        3
# 2014        2
# 2015        1
# 2016        1
# 2017        0
# 2018        0
# 2019        0
# dtype: int64

# %%
list_na={i:schooling.iloc[i].isna().sum() for i in range(len(schooling.index)) if schooling.iloc[i].isna().sum()>0}

# %%
list_na
# Out:
# {5: 15,
#  21: 10,
#  28: 9,
#  53: 10,
#  54: 5,
#  90: 25,
#  98: 9,
#  100: 10,
#  106: 5,
#  109: 26,
#  113: 10,
#  116: 13,
#  121: 10,
#  132: 10,
#  133: 5,
#  149: 20,
#  161: 20,
#  172: 10,
#  178: 10,
#  179: 23,
#  184: 2,
#  187: 9}

# %%
#interpolation works only with numeric columns. So, select numeric columns first
data_numeric=schooling._get_numeric_data().copy()

#select numeric columns with missing data
cols_interp=data_numeric.columns[data_numeric.isnull().sum()>0]
cols_interp
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
#interpolate them
data_numeric[cols_interp]=data_numeric[cols_interp].interpolate(method='linear')

# %%
data_numeric.isna().sum().sum()
# Out:
# 0

# %%
schooling[cols_interp]=data_numeric[cols_interp].interpolate(method='linear')

schooling.columns[schooling.isna().sum()>0]
# Out:
# Index([], dtype='object')

# %%
schooling.iloc[108]
# Out:
# Country     Malta
# 1990         12.9
# 1991         13.1
# 1992         13.2
# 1993         13.3
# 1994         13.4
# 1995         13.4
# 1996         13.4
# 1997         13.5
# 1998         13.9
# 1999         13.8
# 2000         13.7
# 2001         13.8
# 2002         13.8
# 2003         14.2
# 2004         14.8
# 2005         14.8
# 2006         14.4
# 2007         14.6
# 2008         14.4
# 2009         14.6
# 2010         15.3
# 2011         14.9
# 2012           15
# 2013         15.2
# 2014         15.4
# 2015         15.4
# 2016         15.7
# 2017         15.8
# 2018         16.1
# 2019         16.1
# Name: 109, dtype: object

# %%
schooling.to_csv('expected_years_of_schooling_cleaned.csv', index=False)

# %% [markdown]
# # Clean Mean Years of schooling

# %%
os.listdir()
# Out:
# ['Education index.csv',
#  'education_index_cleaned.csv',
#  'Expected years of schooling (years).csv',
#  'expected_years_of_schooling_cleaned.csv',
#  'Life expectancy at birth (years).csv',
#  'Life expectancy at birth.csv',
#  'Life expectancy index.csv',
#  'life_expectancy_cleaned.csv',
#  'life_expectancy_index_cleaned.csv',
#  'Mean years of schooling (years).csv',
#  'Population, total (millions).csv',
#  'population_cleaned.csv',
#  'Total population (millions).csv']

# %%
file='Mean years of schooling (years).csv'

# %%
mean_schooling=pd.read_csv(file)

# %%
mean_schooling.head()
# Out:
#                                             HDI Rank       Country 1990  \
# 0  Mean years of schooling (years)\nSDG 4.4 By 20...           NaN  NaN
# 1                                                169   Afghanistan  1.5
# 2                                                 69       Albania  7.8
# 3                                                 91       Algeria  3.6
# 4                                                 36       Andorra   ..
#
#    Unnamed: 3 1991  Unnamed: 5 1992  Unnamed: 7 1993  Unnamed: 9  ...  2015  \
# 0         NaN  NaN         NaN  NaN         NaN  NaN         NaN  ...   NaN
# 1         NaN  1.6         NaN  1.6         NaN  1.7         NaN  ...   3.6
# 2         NaN  7.8         NaN  7.8         NaN  7.8         NaN  ...  10.0
# 3         NaN  3.8         NaN  4.0         NaN  4.3         NaN  ...   7.9
# 4         NaN   ..         NaN   ..         NaN   ..         NaN  ...  10.6
#
# ...

# %%
mean_schooling.drop(['HDI Rank', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 
           'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23',
           'Unnamed: 25', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31', 'Unnamed: 33', 'Unnamed: 35',
           'Unnamed: 37', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 45', 'Unnamed: 47',
           'Unnamed: 49', 'Unnamed: 51', 'Unnamed: 53', 'Unnamed: 55', 'Unnamed: 57', 'Unnamed: 59',
            'Unnamed: 61'], axis=1, inplace=True)

# %%
mean_schooling.head()
# Out:
#         Country 1990 1991 1992 1993 1994 1995 1996 1997 1998  ...  2010  2011  \
# 0           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN   NaN
# 1   Afghanistan  1.5  1.6  1.6  1.7  1.8  1.9  1.9  2.0  2.0  ...   3.2   3.3
# 2       Albania  7.8  7.8  7.8  7.8  7.8  8.0  8.2  8.3  8.5  ...   9.3  10.0
# 3       Algeria  3.6  3.8  4.0  4.3  4.5  4.7  5.0  5.2  5.4  ...   7.1   7.4
# 4       Andorra   ..   ..   ..   ..   ..   ..   ..   ..   ..  ...  10.4  10.4
#
#    2012  2013  2014  2015  2016  2017  2018  2019
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   3.4   3.5   3.5   3.6   3.6   3.8   3.9   3.9
# 2  10.0  10.0  10.0  10.0  10.0  10.1  10.1  10.1
# 3   7.6   7.8   7.9   7.9   7.9   8.0   8.0   8.0
# 4  10.4  10.5  10.5  10.6  10.6  10.5  10.5  10.5
#
# [5 rows x 31 columns]

# %%
mean_schooling.tail(30)
# Out:
#                                                Country 1990 1991 1992 1993  \
# 190                                           Zimbabwe  4.5  4.7  4.9  5.1
# 191                                  Human Development        ..   ..   ..
# 192                        Very high human development  9.3  9.4  9.6  9.7
# 193                             High human development  4.9  5.1  5.3  5.4
# 194                           Medium human development  3.0  3.1  3.2  3.3
# 195                              Low human development  2.1  2.2  2.3  2.4
# 196                               Developing Countries  4.2  4.4  4.5  4.7
# 197                                            Regions        ..   ..   ..
# 198                                        Arab States  3.3  3.4  3.6  3.7
# 199                          East Asia and the Pacific  4.6  4.8  5.0  5.1
# 200                            Europe and Central Asia  7.5  7.7  7.8  7.9
# ...

# %%
mean_schooling=mean_schooling[1:191]

# %%
mean_schooling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 1 to 190
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  190 non-null    object
#  1   1990     190 non-null    object
#  2   1991     190 non-null    object
#  3   1992     190 non-null    object
#  4   1993     190 non-null    object
#  5   1994     190 non-null    object
#  6   1995     190 non-null    object
#  7   1996     190 non-null    object
#  8   1997     190 non-null    object
#  9   1998     190 non-null    object
#  10  1999     190 non-null    object
#  11  2000     190 non-null    object
#  12  2001     190 non-null    object
#  13  2002     190 non-null    object
#  14  2003     190 non-null    object
#  15  2004     190 non-null    object
#  16  2005     190 non-null    object
#  17  2006     190 non-null    object
#  18  2007     190 non-null    object
#  19  2008     190 non-null    object
# ...

# %%
mean_schooling=mean_schooling.replace('..', '').replace(' ', '')

# %%
# Select the columns to transform it into float excluding the Country column
cols = mean_schooling.columns[mean_schooling.dtypes.eq('object')]
cols=cols.drop('Country')
mean_schooling[cols]=mean_schooling[cols].apply(pd.to_numeric, downcast='float')
mean_schooling.head()
# Out:
#         Country  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 1   Afghanistan   1.5   1.6   1.6   1.7   1.8   1.9   1.9   2.0   2.0  ...
# 2       Albania   7.8   7.8   7.8   7.8   7.8   8.0   8.2   8.3   8.5  ...
# 3       Algeria   3.6   3.8   4.0   4.3   4.5   4.7   5.0   5.2   5.4  ...
# 4       Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5        Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 1   3.2   3.3   3.4   3.5   3.5   3.6   3.6   3.8   3.9   3.9
# 2   9.3  10.0  10.0  10.0  10.0  10.0  10.0  10.1  10.1  10.1
# 3   7.1   7.4   7.6   7.8   7.9   7.9   7.9   8.0   8.0   8.0
# 4  10.4  10.4  10.4  10.5  10.5  10.6  10.6  10.5  10.5  10.5
# 5   4.7   4.7   4.8   4.9   4.9   5.0   5.1   5.1   5.2   5.2
#
# [5 rows x 31 columns]

# %%
mean_schooling.isna().sum()
# Out:
# Country     0
# 1990       42
# 1991       42
# 1992       42
# 1993       42
# 1994       42
# 1995       39
# 1996       39
# 1997       39
# 1998       39
# 1999       37
# 2000       15
# 2001       15
# 2002       14
# 2003       12
# 2004       10
# 2005        4
# 2006        3
# 2007        4
# 2008        3
# 2009        3
# 2010        2
# 2011        1
# 2012        1
# 2013        1
# 2014        1
# 2015        1
# 2016        1
# 2017        1
# 2018        1
# 2019        1
# dtype: int64

# %%
list_na={i:mean_schooling.iloc[i].isna().sum() for i in range(len(mean_schooling.index)) if mean_schooling.iloc[i].isna().sum()>0}

# %%
list_na
# Out:
# {3: 10,
#  4: 9,
#  5: 10,
#  10: 5,
#  11: 10,
#  15: 5,
#  19: 15,
#  21: 10,
#  26: 10,
#  28: 10,
#  33: 10,
#  37: 10,
#  47: 5,
#  48: 10,
#  53: 10,
#  54: 15,
#  57: 10,
#  63: 10,
#  67: 12,
#  70: 15,
#  89: 10,
#  95: 15,
#  102: 10,
#  108: 21,
#  112: 10,
#  115: 13,
#  125: 13,
#  126: 10,
#  128: 10,
#  131: 14,
#  143: 15,
#  144: 10,
#  145: 10,
#  151: 10,
#  156: 9,
#  157: 29,
#  159: 18,
#  163: 14,
#  170: 10,
#  176: 20,
#  183: 10,
#  184: 15}

# %%
#interpolation works only with numeric columns. So, select numeric columns first
data_numeric=mean_schooling._get_numeric_data().copy()

#select numeric columns with missing data
cols_interp=data_numeric.columns[data_numeric.isnull().sum()>0]
cols_interp

#interpolate them
data_numeric[cols_interp]=data_numeric[cols_interp].interpolate(method='linear')

# %%
data_numeric.isna().sum().sum()
# Out:
# 0

# %%
mean_schooling[cols_interp]=data_numeric[cols_interp].interpolate(method='linear')

mean_schooling.columns[mean_schooling.isna().sum()>0]
# Out:
# Index([], dtype='object')

# %%
mean_schooling.to_csv('mean_years_of_schooling_cleaned.csv', index=False)

# %% [markdown]
# # Clean Life expectancy at birth

# %%
os.listdir()
# Out:
# ['Education index.csv',
#  'Expected years of schooling (years).csv',
#  'Life expectancy at birth (years).csv',
#  'Life expectancy at birth.csv',
#  'Life expectancy Index.csv',
#  'life_expectancy_cleaned.csv',
#  'Mean years of schooling (years).csv',
#  'Population, total (millions).csv',
#  'population_cleaned.csv',
#  'Total population (millions).csv']

# %%
file='Life expectancy at birth (years).csv'

# %%
life_expectancy=pd.read_csv(file)

# %%
life_expectancy.head()
# Out:
#                                             HDI Rank       Country  1990  \
# 0  Life expectancy at birth (years)\nSDG 3. Ensur...           NaN   NaN
# 1                                                169   Afghanistan  50.3
# 2                                                 69       Albania  71.8
# 3                                                 91       Algeria  66.9
# 4                                                 36       Andorra  76.5
#
#    Unnamed: 3  1991  Unnamed: 5  1992  Unnamed: 7  1993  Unnamed: 9  ...  \
# 0         NaN   NaN         NaN   NaN         NaN   NaN         NaN  ...
# 1         NaN  51.0         NaN  51.6         NaN  52.3         NaN  ...
# 2         NaN  71.8         NaN  71.8         NaN  71.9         NaN  ...
# 3         NaN  67.3         NaN  67.6         NaN  67.9         NaN  ...
# 4         NaN  76.7         NaN  76.9         NaN  77.0         NaN  ...
#
#    2015  Unnamed: 53  2016  Unnamed: 55  2017  Unnamed: 57  2018  Unnamed: 59  \
# ...

# %%
life_expectancy.drop(['HDI Rank', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 
           'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23',
           'Unnamed: 25', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31', 'Unnamed: 33', 'Unnamed: 35',
           'Unnamed: 37', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 45', 'Unnamed: 47',
           'Unnamed: 49', 'Unnamed: 51', 'Unnamed: 53', 'Unnamed: 55', 'Unnamed: 57', 'Unnamed: 59',
                     'Unnamed: 61'], axis=1, inplace=True)

# %%
life_expectancy.shape
# Out:
# (211, 31)

# %%
life_expectancy.head()
# Out:
#         Country  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 0           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   Afghanistan  50.3  51.0  51.6  52.3  52.8  53.4  53.9  54.4  54.9  ...
# 2       Albania  71.8  71.8  71.8  71.9  72.0  72.2  72.5  72.8  73.2  ...
# 3       Algeria  66.9  67.3  67.6  67.9  68.2  68.5  68.9  69.3  69.7  ...
# 4       Andorra  76.5  76.7  76.9  77.0  77.2  77.4  77.6  77.9  78.2  ...
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  61.0  61.6  62.1  62.5  63.0  63.4  63.8  64.1  64.5  64.8
# 2  76.6  76.9  77.3  77.6  77.8  78.0  78.2  78.3  78.5  78.6
# 3  74.9  75.2  75.4  75.7  75.9  76.1  76.3  76.5  76.7  76.9
# 4  80.8  80.9  81.1  81.2  81.3  81.4  81.5  81.7  81.8  81.9
#
# [5 rows x 31 columns]

# %%
life_expectancy.tail(20)
# Out:
#                                                Country  1990  1991  1992  \
# 191                                           Zimbabwe  58.1  56.7  55.2
# 192                                  Human Development          ..    ..
# 193                        Very high human development  73.8  73.9  74.0
# 194                             High human development  68.0  68.2  68.4
# 195                           Medium human development  58.7  59.1  59.6
# 196                              Low human development  49.1  49.2  49.4
# 197                               Developing Countries  63.0  63.2  63.4
# 198                                            Regions          ..    ..
# 199                                        Arab States  64.4  64.8  65.2
# 200                          East Asia and the Pacific  67.9  68.1  68.2
# 201                            Europe and Central Asia  67.3  67.2  67.1
# 202                    Latin America and the Caribbean  68.3  68.6  69.0
# ...

# %%
life_expectancy=life_expectancy[1:192]

# %%
life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 1 to 191
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  191 non-null    object
#  1   1990     191 non-null    object
#  2   1991     191 non-null    object
#  3   1992     191 non-null    object
#  4   1993     191 non-null    object
#  5   1994     191 non-null    object
#  6   1995     191 non-null    object
#  7   1996     191 non-null    object
#  8   1997     191 non-null    object
#  9   1998     191 non-null    object
#  10  1999     191 non-null    object
#  11  2000     191 non-null    object
#  12  2001     191 non-null    object
#  13  2002     191 non-null    object
#  14  2003     191 non-null    object
#  15  2004     191 non-null    object
#  16  2005     191 non-null    object
#  17  2006     191 non-null    object
#  18  2007     191 non-null    object
#  19  2008     191 non-null    object
# ...

# %%
life_expectancy=life_expectancy.replace('..', '').replace(' ', '')

# %%
# Select the columns to transform it into float excluding the Country column
cols = life_expectancy.columns[life_expectancy.dtypes.eq('object')]
cols=cols.drop('Country')
life_expectancy[cols]=life_expectancy[cols].apply(pd.to_numeric, downcast='float')
life_expectancy.head()
# Out:
#         Country       1990       1991       1992       1993       1994  \
# 1   Afghanistan  50.299999  51.000000  51.599998  52.299999  52.799999
# 2       Albania  71.800003  71.800003  71.800003  71.900002  72.000000
# 3       Algeria  66.900002  67.300003  67.599998  67.900002  68.199997
# 4       Andorra  76.500000  76.699997  76.900002  77.000000  77.199997
# 5        Angola  45.299999  45.299999  45.200001  45.200001  45.200001
#
#         1995       1996       1997       1998  ...       2010       2011  \
# 1  53.400002  53.900002  54.400002  54.900002  ...  61.000000  61.599998
# 2  72.199997  72.500000  72.800003  73.199997  ...  76.599998  76.900002
# 3  68.500000  68.900002  69.300003  69.699997  ...  74.900002  75.199997
# 4  77.400002  77.599998  77.900002  78.199997  ...  80.800003  80.900002
# 5  45.200001  45.400002  45.500000  45.799999  ...  55.400002  56.299999
#
#         2012       2013       2014       2015       2016       2017  \
# ...

# %%
life_expectancy.isna().sum()
# Out:
# Country    0
# 1990       0
# 1991       0
# 1992       0
# 1993       0
# 1994       0
# 1995       0
# 1996       0
# 1997       0
# 1998       0
# 1999       0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# dtype: int64

# %%
life_expectancy.to_csv('life_expectancy_cleaned.csv', index=False)

# %% [markdown]
# ## Life expectancy Index

# %%
os.listdir()
# Out:
# ['Education index.csv',
#  'Expected years of schooling (years).csv',
#  'Life expectancy at birth (years).csv',
#  'Life expectancy at birth.csv',
#  'Life expectancy index.csv',
#  'life_expectancy_cleaned.csv',
#  'Mean years of schooling (years).csv',
#  'Population, total (millions).csv',
#  'population_cleaned.csv',
#  'Total population (millions).csv']

# %%
file='Life expectancy Index.csv'

# %%
life_index=pd.read_csv('Life expectancy Index.csv')

# %%
life_index.head()
# Out:
#                                             HDI Rank       Country   1990  \
# 0  Life expectancy index\nnull\nDimension: Health...           NaN    NaN
# 1                                                169   Afghanistan  0.467
# 2                                                 69       Albania  0.797
# 3                                                 91       Algeria  0.722
# 4                                                 36       Andorra  0.870
#
#    Unnamed: 3   1991  Unnamed: 5   1992  Unnamed: 7   1993  Unnamed: 9  ...  \
# 0         NaN    NaN         NaN    NaN         NaN    NaN         NaN  ...
# 1         NaN  0.477         NaN  0.487         NaN  0.496         NaN  ...
# 2         NaN  0.797         NaN  0.797         NaN  0.798         NaN  ...
# 3         NaN  0.727         NaN  0.732         NaN  0.737         NaN  ...
# 4         NaN  0.872         NaN  0.875         NaN  0.877         NaN  ...
#
# ...

# %%
life_index.drop(['HDI Rank', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 
           'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23',
           'Unnamed: 25', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31', 'Unnamed: 33', 'Unnamed: 35',
           'Unnamed: 37', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 45', 'Unnamed: 47',
           'Unnamed: 49', 'Unnamed: 51', 'Unnamed: 53', 'Unnamed: 55', 'Unnamed: 57', 'Unnamed: 59',
                'Unnamed: 61'], axis=1, inplace=True)

# %%
life_index.head()
# Out:
#         Country   1990   1991   1992   1993   1994   1995   1996   1997  \
# 0           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   Afghanistan  0.467  0.477  0.487  0.496  0.505  0.514  0.522  0.530
# 2       Albania  0.797  0.797  0.797  0.798  0.800  0.803  0.808  0.813
# 3       Algeria  0.722  0.727  0.732  0.737  0.741  0.747  0.753  0.759
# 4       Andorra  0.870  0.872  0.875  0.877  0.880  0.883  0.887  0.891
#
#     1998  ...   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  0.537  ...  0.631  0.639  0.647  0.654  0.661  0.667  0.673  0.679  0.684
# 2  0.819  ...  0.870  0.876  0.881  0.885  0.889  0.893  0.895  0.897  0.899
# 3  0.765  ...  0.845  0.849  0.853  0.856  0.860  0.863  0.866  0.869  0.872
# 4  0.896  ...  0.936  0.937  0.939  0.941  0.943  0.945  0.947  0.949  0.951
#
#     2019
# 0    NaN
# 1  0.690
# 2  0.901
# 3  0.875
# 4  0.952
#
# ...

# %%
life_index.tail(20)
# Out:
#                                                Country   1990   1991   1992  \
# 190                                             Zambia  0.450  0.433  0.415
# 191                                           Zimbabwe  0.586  0.565  0.542
# 192                                  Human Development            ..     ..
# 193                        Very high human development  0.827  0.829  0.831
# 194                             High human development  0.738  0.741  0.744
# 195                           Medium human development  0.596  0.602  0.609
# 196                              Low human development  0.448  0.450  0.452
# 197                               Developing Countries  0.661  0.665  0.668
# 198                                            Regions            ..     ..
# 199                                        Arab States  0.683  0.689  0.695
# 200                          East Asia and the Pacific  0.737  0.740  0.742
# ...

# %%
life_index=life_index[1:192]

# %%
life_index.shape
# Out:
# (191, 31)

# %%
life_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 1 to 191
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  191 non-null    object
#  1   1990     191 non-null    object
#  2   1991     191 non-null    object
#  3   1992     191 non-null    object
#  4   1993     191 non-null    object
#  5   1994     191 non-null    object
#  6   1995     191 non-null    object
#  7   1996     191 non-null    object
#  8   1997     191 non-null    object
#  9   1998     191 non-null    object
#  10  1999     191 non-null    object
#  11  2000     191 non-null    object
#  12  2001     191 non-null    object
#  13  2002     191 non-null    object
#  14  2003     191 non-null    object
#  15  2004     191 non-null    object
#  16  2005     191 non-null    object
#  17  2006     191 non-null    object
#  18  2007     191 non-null    object
#  19  2008     191 non-null    object
# ...

# %%
life_index=life_index.replace('..', '').replace(' ', '')

# %%
# Select the columns to transform it into float excluding the Country column
cols = life_index.columns[life_index.dtypes.eq('object')]
cols=cols.drop('Country')
life_index[cols]=life_index[cols].apply(pd.to_numeric, downcast='float')
life_index.head()
# Out:
#         Country   1990   1991   1992   1993   1994   1995   1996   1997  \
# 1   Afghanistan  0.467  0.477  0.487  0.496  0.505  0.514  0.522  0.530
# 2       Albania  0.797  0.797  0.797  0.798  0.800  0.803  0.808  0.813
# 3       Algeria  0.722  0.727  0.732  0.737  0.741  0.747  0.753  0.759
# 4       Andorra  0.870  0.872  0.875  0.877  0.880  0.883  0.887  0.891
# 5        Angola  0.389  0.389  0.388  0.388  0.388  0.388  0.390  0.393
#
#     1998  ...   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 1  0.537  ...  0.631  0.639  0.647  0.654  0.661  0.667  0.673  0.679  0.684
# 2  0.819  ...  0.870  0.876  0.881  0.885  0.889  0.893  0.895  0.897  0.899
# 3  0.765  ...  0.845  0.849  0.853  0.856  0.860  0.863  0.866  0.869  0.872
# 4  0.896  ...  0.936  0.937  0.939  0.941  0.943  0.945  0.947  0.949  0.951
# 5  0.396  ...  0.544  0.559  0.573  0.585  0.597  0.606  0.614  0.621  0.627
#
#     2019
# 1  0.690
# 2  0.901
# 3  0.875
# 4  0.952
# 5  0.633
#
# ...

# %%
life_index.isna().sum()
# Out:
# Country    0
# 1990       0
# 1991       0
# 1992       0
# 1993       0
# 1994       0
# 1995       0
# 1996       0
# 1997       0
# 1998       0
# 1999       0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# dtype: int64

# %%
life_index.to_csv('life_expectancy_index_cleaned.csv', index=False)

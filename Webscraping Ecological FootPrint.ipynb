# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
url='https://en.wikipedia.org/wiki/List_of_countries_by_ecological_footprint'

# %%
response=r.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries by ecological footprint - Wikipedia</title>
# ...

# %%
titles=soup.select('table th')
country=soup.select('table tr td a')
#table th [class="headerSort"] title

# %%
titles=[i.text for i in titles]
country=[i.text for i in country]

# %%
xpath="1"

# %%
footprint=soup.find('table',{'class':"wikitable"})

# %%
df=pd.read_html(str(footprint))
# convert list to dataframe
df=pd.DataFrame(df[0])
df.head()
# Out:
#   Rank Country/Region EcologicalFootprint  Biocapacity  \
#   Rank Country/Region        (gha/person) (gha/person)
# 0  NaN          World                2.75         1.63
# 1  1.0     Luxembourg               15.82         1.68
# 2  2.0          Aruba               11.88         0.57
# 3  3.0          Qatar               10.80         1.24
# 4  4.0      Australia                9.31        16.57
#
#   Biocapacitydeficit orreserve Population(millions)  \
#                   (gha/person) Population(millions)
# 0                        -1.12              7000.00
# 1                       −14.14                 0.52
# 2                       −11.31                 0.10
# 3                        −9.56                 2.05
# 4                         7.26                23.05
#
#   Total Biocapacity deficit or reserve (gMha)  \
#   Total Biocapacity deficit or reserve (gMha)
# 0                                      -10400
# 1                                       −7.35
# ...

# %%
df=df.T.reset_index().drop('level_1', axis=1)

# %%
df=df.set_index('level_0').T

# %%
test=df.drop('Rank', axis=1)

# %%
df.to_csv('ecological_footprint.csv')
